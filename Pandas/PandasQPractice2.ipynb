# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Select employees:
#
#     a. with salary greater than 70,000
#
#     b. who work in the IT department
#
#     c. who are active and have performance_score ≥ 4
#
#
# 2. Get all rows where city is Kathmandu or Pokhara.
#
# 3. Select only these columns:
#     id, department, salary, performance_score
#
# 4. Find employees whose experience is between 5 and 10 years.
#
# 5. Filter female employees earning more than the average salary.

# %%
# 1.Select employees:

# a. with salary greater than 70,000
# b. who work in the IT department
# c. who are active and have performance_score ≥ 4

data = pd.read_csv('Dataset.csv')

print("Staff who has salary more than 70k: \n",data[data.salary>70000])
print()

print("Department with IT staff only: \n",data[data["department"]=="IT"])
print()
print("Staff with status active and performance score greater equal than 4: \n"
,data[(data.is_active==True)&(data.performance_score >= 4)])
# Out:
# Staff who has salary more than 70k:
#      id  age  salary department  experience_years        city  \
# 2    3   32   98603         HR                 3   Kathmandu
# 3    4   25   72256    Finance                 2      Butwal
# 4    5   38  109135         IT                16  Biratnagar
# 6    7   36   97373  Marketing                11   Kathmandu
# 7    8   40   99575         IT                13  Biratnagar
# 8    9   28  116354  Marketing                 5      Butwal
# 9   10   28  104651    Finance                 2  Biratnagar
# 10  11   41   83335    Finance                 8     Pokhara
# 13  14   41   90592  Marketing                13  Biratnagar
# 14  15   20  118018         IT                 2   Kathmandu
# 16  17   19   99309         HR                19     Pokhara
# 18  19   47   72992  Marketing                 2      Butwal
# 19  20   55  102948    Finance                17  Biratnagar
# 20  21   19  118806      Sales                 9     Pokhara
# ...

# %%
data[data['city']=='Kathmandu']
# Out:
#      id  age  salary department  experience_years       city  \
# 2     3   32   98603         HR                 3  Kathmandu
# 6     7   36   97373  Marketing                11  Kathmandu
# 14   15   20  118018         IT                 2  Kathmandu
# 26   27   44   43419    Finance                 1  Kathmandu
# 31   32   20   38141  Marketing                 0  Kathmandu
# 39   40   42  101734         HR                12  Kathmandu
# 40   41   31   95450         IT                 6  Kathmandu
# 47   48   25   22693  Marketing                15  Kathmandu
# 48   49   52  115003         HR                13  Kathmandu
# 60   61   43   64262  Marketing                10  Kathmandu
# 68   69   31   29474         HR                 3  Kathmandu
# 77   78   58   86199         HR                12  Kathmandu
# 80   81   18  113557  Marketing                18  Kathmandu
# 84   85   41   74384    Finance                 8  Kathmandu
# ...
